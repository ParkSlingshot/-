# %% [markdown]
# <a href="https://colab.research.google.com/github/ParkSlingshot/-/blob/main/First_step_of_OpenCV.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
upload_image = files.upload()
# Out:
#      <input type="file" id="files-1da519a5-9168-4402-8b45-654c76f9a16f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1da519a5-9168-4402-8b45-654c76f9a16f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving cat.jpg to cat.jpg

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
img = cv2.imread('cat.jpg')
gray_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
luv_img = cv2.cvtColor(img, cv2.COLOR_BGR2Luv)

# %%
#Show image
from google.colab.patches import cv2_imshow
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=275x183 at 0x7F7B5DA8CE90>

# %%
cv2_imshow(gray_img)
# Out:
# <PIL.Image.Image image mode=L size=275x183 at 0x7F7B5D9EF8D0>

# %%
cv2_imshow(luv_img)
# Out:
# <PIL.Image.Image image mode=RGB size=275x183 at 0x7F7B5D9905D0>
