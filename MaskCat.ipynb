# %% [markdown]
# <a href="https://colab.research.google.com/github/ParkSlingshot/-/blob/main/MaskCat.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
upload_image = files.upload()
# Out:
#      <input type="file" id="files-554fd600-1521-4f4b-8e71-0441d4bb63a3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-554fd600-1521-4f4b-8e71-0441d4bb63a3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving cat.jpg to cat.jpg

# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt
import cv2
from google.colab.patches import cv2_imshow

# %%
image = cv2.imread('cat.jpg')
gray_image = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)

# %%
cv2_imshow(image)
print("width = {} pixels".format(image.shape[1]))
print("height = {} pixels".format(image.shape[0]))
print("channel = {}".format(image.shape[2]))
# Out:
# <PIL.Image.Image image mode=RGB size=275x183 at 0x7FE231105750>
# width = 275 pixels
# height = 183 pixels
# channel = 3

# %%
x = 100#@param{type:"slider", min:0, max:275, step:1}
y = 53#@param{type:"slider", min:0, max:183, step:1}
size = 41#@param{type:"slider", min:0, max:275, step:1}

# %%
(b,g,r) = image[x,y]
print("pixel at ({},{}) - RED : {}, GREEN : {}, BLUE : {}".format(x,y,r,g,b))
# Out:
# pixel at (0,0) - RED : 225, GREEN : 208, BLUE : 201

# %%
croped = image[y:y+size, x:x+size]
cv2_imshow(croped)
# Out:
# <PIL.Image.Image image mode=RGB size=65x65 at 0x7FE23122CDD0>

# %%
#Draw the sqaure
#image[y:y+size, x:x+size] = (0,0,255)
#cv2.rectangle(image,(x+size*2, y),(x+size*3,y+size),(0,255,230),5)
#cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=275x183 at 0x7FE2311C5550>

# %%
#Draw the circle
radius = int(size)
cv2.circle(image,(x+size+25,y+40),radius,(0,150,45),2)
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=275x183 at 0x7FE231149110>

# %%
#Line
#cv2.line(image,(x+size*5,y+size*3),(x+size*2,y+size*7),(112,23,200))
#cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=275x183 at 0x7FE231220CD0>

# %%
#Text
cv2.putText(image,'Cat',(x+size+10,y-20),cv2.FONT_HERSHEY_PLAIN,1,(255,30,189))
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=275x183 at 0x7FE231171F90>
