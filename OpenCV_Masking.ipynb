# %% [markdown]
# <a href="https://colab.research.google.com/github/ParkSlingshot/-/blob/main/OpenCV_Masking.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import cv2 as cv
from google.colab.patches import cv_imshow
import matplotlib.pyplot as plt

# %%
from google.colab import files
upload_file = files.upload()
# Out:
#      <input type="file" id="files-0695df58-6daf-42da-ae88-6e5a30d38ac6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0695df58-6daf-42da-ae88-6e5a30d38ac6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving cat.jpg to cat (1).jpg

# %%
image = cv.imread('cat.jpg')

def rescale (frame, scale = 2):
  width = int(frame.shape[1]*scale)
  height = int(frame.shape[0]*scale)
  dimension = (width, height)
  return cv.resize(frame, dimension, interpolation = cv.INTER_AREA)
img = rescale(image)
cv_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=550x366 at 0x7F463344EAD0>

# %%
#Masking on center of blank
blank = np.zeros(img.shape[:2], dtype='uint8')
mask = cv.circle(blank, (img.shape[1]//2, img.shape[0]//2), 50 , (222,111,44), -1)
cv_imshow( mask)
# Out:
# <PIL.Image.Image image mode=L size=550x366 at 0x7F462612E590>

# %%
plt.imshow(mask)

# %%
full_mask = cv.circle(blank, (img.shape[1]//2,img.shape[0]//2), int(img.shape[0]/2), (255), -1)
cv_imshow(full_mask)
# Out:
# <PIL.Image.Image image mode=L size=550x366 at 0x7F462665C850>

# %%
#masking cat
masked = cv.bitwise_and(img,img,mask=mask)
cv_imshow( masked)
# Out:
# <PIL.Image.Image image mode=RGB size=550x366 at 0x7F4626099B10>

# %%
#full_masking cat
full_masking = cv.bitwise_and(img,img,mask=full_mask)
cv_imshow(full_masking)
# Out:
# <PIL.Image.Image image mode=RGB size=550x366 at 0x7F4621F8A050>
